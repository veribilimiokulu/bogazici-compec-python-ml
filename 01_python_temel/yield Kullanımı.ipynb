# %% [markdown]
#     yield deyimi, return deyimi gibi fonksiyonlarda kullanılır, ancak, fonksiyon bir generator döndürür.

# %%
def sonuclari_yiginla(liste):
    for x in liste:
     yield x * x

# %%
sonuclar = sonuclari_yiginla([1,2,3,4,5])

# %%
for k in sonuclar:
   print(k)
# Out:
# 1
# 4
# 9
# 16
# 25
