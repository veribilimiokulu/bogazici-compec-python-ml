# %%
# Listelere benzerler

# %%
# Tuple tanımlama
tuple1 = ("Elma","Kiraz","Kavun")

# %%
type(tuple1)
# Out:
# tuple

# %%
tuple2 = "Muz","Erik",7.8, 5.5

# %%
type(tuple2)
# Out:
# tuple

# %%
tuple3 = tuple("Portakal")
print(tuple3)
# Out:
# ('P', 'o', 'r', 't', 'a', 'k', 'a', 'l')

# %%
python_liste = ["Muz","Erik",7.8, 5.5]
tuple4 = tuple(python_liste)

# %%
print(tuple4)
# Out:
# ('Muz', 'Erik', 7.8, 5.5)

# %% [markdown]
# # Tek Elemanlı Tuple

# %%
tuple5 = ("Vişne")

# %%
type(tuple5)
# Out:
# str

# %%
tuple6 = ("Vişne",)
type(tuple6)
# Out:
# tuple

# %%
tuple7 = "Ananas",
type(tuple7)
# Out:
# tuple

# %% [markdown]
# # Demetlerin Elemanlarına Erişmek

# %%
print(tuple4[0])
# Out:
# Muz

# %%
print(tuple4[-1])
# Out:
# 5.5

# %%
print(tuple4[:])
# Out:
# ('Muz', 'Erik', 7.8, 5.5)

# %% [markdown]
# # Demetlerle Listelerin Farkı

# %% [markdown]
# ## 1. En önemli fark listeler değiştirilebilir yani mutable iken tuples değiştirilemez yani immutable

# %%
# tuple4'ün 0. indisindeki değeri değiştirmeyeçalışalım
tuple4[0] = "Şeftali"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-13cb2b955e52> in <module>
#       1 # tuple4'ün 0. indisindeki değeri değiştirmeyeçalışalım
# ----> 2 tuple4[0] = "Şeftali"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## 2. Immutable olduğu için listelerden hızlıdır

# %% [markdown]
# # Tuples Ekleme

# %%
tuple4 = tuple4 + tuple6
print(tuple4)
# Out:
# ('Muz', 'Erik', 7.8, 5.5, 'Vişne')

# %%
tuple4 += tuple6
print(tuple4)
# Out:
# ('Muz', 'Erik', 7.8, 5.5, 'Vişne', 'Vişne')
